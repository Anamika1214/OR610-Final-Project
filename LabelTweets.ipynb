# %%
# !pip install textblob
# !pip install plotly

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from textblob import TextBlob
import re
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# %%
ls
# Out:
# drive/  sample_data/  trump_tweets  trump_tweets.csv

# %%
df = pd.read_csv('drive/MyDrive/Colab Notebooks/tweets_11-06-2020.csv')

# %%
df.head()
# Out:
#                     id  ...                 date
# 0    98454970654916608  ...  2011-08-02 18:07:48
# 1  1234653427789070336  ...  2020-03-03 01:34:50
# 2  1218010753434820614  ...  2020-01-17 03:22:47
# 3  1304875170860015617  ...  2020-09-12 20:10:58
# 4  1218159531554897920  ...  2020-01-17 13:13:59
#
# [5 rows x 8 columns]

# %%
for tweet in df.text[:5]:
    print(tweet)
    print()
# Out:
# Republicans and Democrats have both created our economic problems.
#
# I was thrilled to be back in the Great city of Charlotte, North Carolina with thousands of hardworking American Patriots who love our Country, cherish our values, respect our laws, and always put AMERICA FIRST! Thank you for a wonderful evening!! #KAG2020 https://t.co/dNJZfRsl9y
#
# RT @CBS_Herridge: READ: Letter to surveillance court obtained by CBS News questions where there will be further disciplinary action and cho…
#
# The Unsolicited Mail In Ballot Scam is a major threat to our Democracy, &amp; the Democrats know it. Almost all recent elections using this system, even though much smaller &amp;  with far fewer Ballots to count, have ended up being a disaster. Large numbers of missing Ballots &amp; Fraud!
#
# RT @MZHemingway: Very friendly telling of events here about Comey's apparent leaking to compliant media. If you read those articles and tho…

# %%
data = pd.DataFrame(data=[tweet for tweet in df.text], columns=['Tweets'])

# %%
data.head(10)
# Out:
#                                               Tweets
# 0  Republicans and Democrats have both created ou...
# 1  I was thrilled to be back in the Great city of...
# 2  RT @CBS_Herridge: READ: Letter to surveillance...
# 3  The Unsolicited Mail In Ballot Scam is a major...
# 4  RT @MZHemingway: Very friendly telling of even...
# 5  RT @WhiteHouse: President @realDonaldTrump ann...
# 6  “I’m running as a proud Democrat, for the Sena...
# 7  Getting a little exercise this morning! https:...
# 8                            https://t.co/4qwCKQOiOw
# 9                            https://t.co/VlEu8yyovv

# %%
data['len']  = np.array([len(tweet) for tweet in df.text])
data['ID']   = np.array([ids for ids in df.id])
data['Date'] = np.array([dt for dt in df.date])
#data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([fv for fv in df.favorites])
data['RTs']    = np.array([rt for rt in df.retweets])

# %%
data.head()
# Out:
#                                               Tweets  len  ...  Likes    RTs
# 0  Republicans and Democrats have both created ou...   66  ...     49    255
# 1  I was thrilled to be back in the Great city of...  279  ...  73748  17404
# 2  RT @CBS_Herridge: READ: Letter to surveillance...  140  ...      0   7396
# 3  The Unsolicited Mail In Ballot Scam is a major...  290  ...  80527  23502
# 4  RT @MZHemingway: Very friendly telling of even...  140  ...      0   9081
#
# [5 rows x 6 columns]

# %%
data.dtypes
# Out:
# Tweets    object
# len        int64
# ID         int64
# Date      object
# Likes      int64
# RTs        int64
# dtype: object

# %%
#mask = (data['Date'] > '2019-01-01') & (data['Date'] <= '2020-10-10')

# %%
#df1 = data.loc[mask]

# %%
#df1.head()
#df1.shape
# Out:
# (17399, 6)

# %%
df1 = data[data['Date'] > '2019-01-01']

# %%
df1.head(20)
# Out:
#                                                Tweets  len  ...   Likes    RTs
# 1   I was thrilled to be back in the Great city of...  279  ...   73748  17404
# 2   RT @CBS_Herridge: READ: Letter to surveillance...  140  ...       0   7396
# 3   The Unsolicited Mail In Ballot Scam is a major...  290  ...   80527  23502
# 4   RT @MZHemingway: Very friendly telling of even...  140  ...       0   9081
# 5   RT @WhiteHouse: President @realDonaldTrump ann...  140  ...       0  25048
# 6   “I’m running as a proud Democrat, for the Sena...  165  ...  149007  34897
# 7   Getting a little exercise this morning! https:...   63  ...  285863  30209
# 8                             https://t.co/4qwCKQOiOw   23  ...  130822  19127
# 9                             https://t.co/VlEu8yyovv   23  ...  153446  20275
# 10                            https://t.co/z5CRqHO8vg   23  ...  102150  14815
# 11                            https://t.co/TQCQiDrVOB   23  ...  255804  35594
# ...

# %%
from textblob import TextBlob
import re

# %%
def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %%
def analyze_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
df1.Tweets
# Out:
# 1        I was thrilled to be back in the Great city of...
# 2        RT @CBS_Herridge: READ: Letter to surveillance...
# 3        The Unsolicited Mail In Ballot Scam is a major...
# 4        RT @MZHemingway: Very friendly telling of even...
# 5        RT @WhiteHouse: President @realDonaldTrump ann...
#                                ...
# 55080    RT @heatherjones333: MAGNIFICENT TRUMP- KEEPIN...
# 55081    RT @heatherjones333: 🔥🔥🔥🔥🔥Lindsey Graham: Trum...
# 55082    RT @heatherjones333: Congratulations Sleepy Jo...
# 55083    RT @heatherjones333: DEAR STUPID PEOPLE- PEACE...
# 55084    RT @heatherjones333: 'We Have Taken Appropriat...
# Name: Tweets, Length: 17399, dtype: object

# %%
df1['SA'] = np.array([ analyze_sentiment(tweet) for tweet in df1['Tweets'] ])

# %%
df1.shape
df1.head()
# Out:
#                                               Tweets  len  ...    RTs SA
# 1  I was thrilled to be back in the Great city of...  279  ...  17404  1
# 2  RT @CBS_Herridge: READ: Letter to surveillance...  140  ...   7396  1
# 3  The Unsolicited Mail In Ballot Scam is a major...  290  ...  23502  1
# 4  RT @MZHemingway: Very friendly telling of even...  140  ...   9081  1
# 5  RT @WhiteHouse: President @realDonaldTrump ann...  140  ...  25048  1
#
# [5 rows x 7 columns]

# %%
pos_tweets = [ tweet for index, tweet in enumerate(df1['Tweets']) if df1['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(df1['Tweets']) if df1['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(df1['Tweets']) if df1['SA'][index] < 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-21f3d738fc9e> in <module>()
# ...

# %%
print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Percentage of positive tweets: 53.06952259938283%
# Percentage of neutral tweets: 28.865492829914686%
# Percentage de negative tweets: 18.064984570702485%

# %%
data.to_csv('trump_tweets.csv', index=False)
