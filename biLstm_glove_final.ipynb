# %%
import pandas as pd
import numpy as np
import time
import spacy
import random
from pathlib import Path
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchtext import data 
import torchtext
from nltk.tokenize.treebank import TreebankWordDetokenizer
import itertools
import matplotlib.pyplot as plt

# %%
# Setting device on GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')

torch.backends.cudnn.deterministic = True
# Out:
# Using device: cuda
#
# Tesla P100-PCIE-16GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# /usr/local/lib/python3.6/dist-packages/torch/cuda/memory.py:346: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
TEXT = data.Field(tokenize='spacy', lower=True, include_lengths= True)
LABEL = data.LabelField(dtype=torch.float)

# Map data to fields
fields = [('target', LABEL), ('id',None),('date',None),('query',None),
      ('name',None), ('text', TEXT),('category',None)]

# Apply field definition to create torch dataset
dataset = torchtext.data.TabularDataset(
        path="/content/drive/MyDrive/Colab Notebooks/tweet_final1.csv",
        format="CSV",
        fields=fields,
        skip_header=False)

# %%
# Split data into train, test, validation sets
(train_data, test_data, valid_data) = dataset.split(split_ratio=[0.8,0.1,0.1])

print("Number of train data: {}".format(len(train_data)))
print("Number of test data: {}".format(len(test_data)))
print("Number of validation data: {}".format(len(valid_data)))
# Out:
# Number of train data: 79866
# Number of test data: 9983
# Number of validation data: 9983

# %%
cd /content/.vector_cache/
# Out:
# [Errno 2] No such file or directory: '/content/.vector_cache/'
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %%
from google.colab import files
files.download('lstmG-best.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-6fa5708bb35d> in <module>()
#       1 from google.colab import files
# ----> 2 files.download('lstmG-best.pt')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     141       raise OSError(msg)
#     142     else:
# --> 143       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     144
#     145   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: lstmG-best.pt

# %%
rm -r /content/.vector_cache/glove.6B.zip
# Out:
# rm: cannot remove '/content/.vector_cache/glove.6B.zip': No such file or directory

# %% [markdown]
# ### Build Vocabulary using GloVe

# %%
MAX_VOCAB_SIZE = 30000
TEXT.build_vocab(train_data, 
                 max_size = MAX_VOCAB_SIZE,
                 vectors = "glove.6B.100d",
                 unk_init = torch.Tensor.normal_)

LABEL.build_vocab(train_data)
TEXT.vocab.freqs.most_common(10)
# Out:
# .vector_cache/glove.6B.zip: 862MB [06:27, 2.23MB/s]
# 100%|█████████▉| 398020/400000 [00:15<00:00, 25015.79it/s]
# [('i', 49523),
#  ('!', 44756),
#  ('.', 39881),
#  ('to', 28046),
#  ('the', 26267),
#  (',', 23804),
#  ('a', 19065),
#  ('my', 15788),
#  ('you', 15221),
#  ('and', 15106)]

# %%
BATCH_SIZE = 500

# sort_within_batch sorts all the tensors within a batch by their lengths
train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data),
    device = device,
    batch_size = BATCH_SIZE,
    sort_key = lambda x: len(x.text),
    sort_within_batch = True)

# %% [markdown]
# ### Define Model

# %%
class LSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, 
                 bidirectional, dropout, pad_idx):
        """
        Define the layers of the module.

        vocab_size - vocabulary size
        embedding_dim - size of the dense word vectors
        hidden_dim - size of the hidden states
        output_dim - number of classes
        n_layers - number of multi-layer RNN
        bidirectional - boolean - use both directions of LSTM
        dropout - dropout probability
        pad_idx -  string representing the pad token
        """
        
        super().__init__()

        # 1. Feed the tweets in the embedding layer
        # padding_idx set to not learn the emedding for the <pad> token - irrelevant to determining sentiment
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx = pad_idx)

        # 2. LSTM layer
        # returns the output and a tuple of the final hidden state and final cell state
        self.encoder = nn.LSTM(embedding_dim, 
                               hidden_dim, 
                               num_layers=n_layers,
                               bidirectional=bidirectional,
                               dropout=dropout)
        
        # 3. Fully-connected layer
        # Final hidden state has both a forward and a backward component concatenated together
        # The size of the input to the nn.Linear layer is twice that of the hidden dimension size
        self.predictor = nn.Linear(hidden_dim*2, output_dim)

        # Initialize dropout layer for regularization
        self.dropout = nn.Dropout(dropout)
      
    def forward(self, text, text_lengths):
        """
        The forward method is called when data is fed into the model.

        text - [tweet length, batch size]
        text_lengths - lengths of tweet
        """

        # embedded = [sentence len, batch size, emb dim]
        embedded = self.dropout(self.embedding(text))    
        #seq_lengths_clamped = text_lengths.clamp(min=1, max=self.max_length)
        # Pack the embeddings - cause RNN to only process non-padded elements
        # Speeds up computation
        #text_lengths = torch.as_tensor(text_lengths, dtype=torch.int64, device='cpu')
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths)

        # output of encoder
        packed_output, (hidden, cell) = self.encoder(packed_embedded)

        # unpack sequence - transform packed sequence to a tensor
        output, output_lengths = nn.utils.rnn.pad_packed_sequence(packed_output)

        # output = [sentence len, batch size, hid dim * num directions]
        # output over padding tokens are zero tensors
        
        # hidden = [num layers * num directions, batch size, hid dim]
        # cell = [num layers * num directions, batch size, hid dim]
        
        # Get the final layer forward and backward hidden states  
        # concat the final forward and backward hidden layers and apply dropout
        hidden = self.dropout(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1))

        # hidden = [batch size, hid dim * num directions]

        return self.predictor(hidden)

# %% [markdown]
# ### Initialize the model with parameters

# %%
####(0.4, 100, 50, 'Adam', 0.01)

INPUT_DIM = len(TEXT.vocab)
# dim must be equal to the dim of pre-trained GloVe vectors
EMBEDDING_DIM = 100
HIDDEN_DIM = 256
OUTPUT_DIM = 1
# 2 layers of biLSTM
N_LAYERS = 2
BIDIRECTIONAL = True
# Dropout probability
DROPOUT = 0.6
# Get pad token index from vocab
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]

# Create an instance of LSTM class
model = LSTM(INPUT_DIM,
            EMBEDDING_DIM,
            HIDDEN_DIM,
            OUTPUT_DIM,
            N_LAYERS,
            BIDIRECTIONAL,
            DROPOUT,
            PAD_IDX)

# %%
pretrained_embeddings = TEXT.vocab.vectors

# [vocab size, embedding dim]
print(pretrained_embeddings.shape)
# Out:
# torch.Size([30002, 100])

# %%
model.embedding.weight.data.copy_(pretrained_embeddings)
# Out:
# tensor([[ 0.0648,  1.7650,  2.0839,  ..., -0.8507, -1.4882,  0.3546],
#         [ 0.1727, -0.6275,  0.1919,  ..., -1.5999, -0.2273, -1.0276],
#         [-0.0465,  0.6197,  0.5665,  ..., -0.3762, -0.0325,  0.8062],
#         ...,
#         [ 0.8022,  0.5696, -1.9199,  ...,  1.4209,  0.9100, -0.4217],
#         [ 0.1325,  0.2403,  0.6837,  ..., -0.9995, -0.4557,  0.5032],
#         [-0.5211,  0.8410, -0.4404,  ...,  1.2410, -0.1239,  1.0260]])

# %%
UNK_IDX = TEXT.vocab.stoi[TEXT.unk_token]

# Setting row in the embedding weights matrix to zero using the token index
model.embedding.weight.data[UNK_IDX] = torch.zeros(EMBEDDING_DIM)
model.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)

print(model.embedding.weight.data)
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.0465,  0.6197,  0.5665,  ..., -0.3762, -0.0325,  0.8062],
#         ...,
#         [ 0.8022,  0.5696, -1.9199,  ...,  1.4209,  0.9100, -0.4217],
#         [ 0.1325,  0.2403,  0.6837,  ..., -0.9995, -0.4557,  0.5032],
#         [-0.5211,  0.8410, -0.4404,  ...,  1.2410, -0.1239,  1.0260]])

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)
#optimizer = optim.RMSprop(model.parameters(),lr=0.001)

criterion = nn.BCEWithLogitsLoss()

# Use GPU
model = model.to(device)
criterion = criterion.to(device)

# %%
def batch_accuracy(predictions, label):
    """
    Returns accuracy per batch.

    predictions - float
    label - 0 or 1
    """

    # Round predictions to the closest integer using the sigmoid function
    preds = torch.round(torch.sigmoid(predictions))
    # If prediction is equal to label
    correct = (preds == label).float()
    # Average correct predictions
    accuracy = correct.sum() / len(correct)

    return accuracy

def timer(start_time, end_time):
    """
    Returns the minutes and seconds.
    """

    time = end_time - start_time
    mins = int(time / 60)
    secs = int(time - (mins * 60))

    return mins, secs

# %%
def train(model, iterator, optimizer, criterion):

    clip=5    
    # Cumulated Training loss
    training_loss = 0.0
    # Cumulated Training accuracy
    training_acc = 0.0
    
    # Set model to training mode
    model.train()
    
    # For each batch in the training iterator
    for batch in iterator:
        
        # 1. Zero the gradients
        optimizer.zero_grad()
        
        # batch.text is a tuple (tensor, len of seq)
        text, text_lengths = batch.text
        text_lengths = torch.as_tensor(text_lengths, dtype=torch.int64, device='cpu')
        
        # 2. Compute the predictions
        predictions = model(text, text_lengths).squeeze(1)
        
        # 3. Compute loss
        loss = criterion(predictions, batch.target)
        
        # Compute accuracy
        accuracy = batch_accuracy(predictions, batch.target)
        
        # 4. Use loss to compute gradients
        loss.backward()

        nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        # 5. Use optimizer to take gradient step
        optimizer.step()
        
        training_loss += loss.item()
        training_acc += accuracy.item()
    
    # Return the loss and accuracy, averaged across each epoch
    # len of iterator = num of batches in the iterator
    return training_loss / len(iterator), training_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    """
    Function to evaluate the loss and accuracy of validation and test sets.

    iterator - validation or test iterator
    """
    
    # Cumulated Training loss
    eval_loss = 0.0
    # Cumulated Training accuracy
    eval_acc = 0
    
    # Set model to evaluation mode
    model.eval()
    
    # Don't calculate the gradients
    with torch.no_grad():
    
        for batch in iterator:

            text, text_lengths = batch.text
            text_lengths = torch.as_tensor(text_lengths, dtype=torch.int64, device='cpu')
            
            predictions = model(text, text_lengths).squeeze(1)
            
            loss = criterion(predictions, batch.target)
            
            accuracy = batch_accuracy(predictions, batch.target)

            eval_loss += loss.item()
            eval_acc += accuracy.item()
        
    return eval_loss / len(iterator), eval_acc / len(iterator)

# %%
##Grid Search to find best hyperparameters

GRID_DROPOUT = [.5, .75, .4]
HIDDEN_DIM = [64,100,256]
GRID_EMBED_DIM = [50,100,300]
GRID_OPT_SELECT = ["Adam","RMSprop"]
#GRID_LR = [0.01,0.001,0.0001]
GRID_LR = [0.1,0.01,0.001]

GRID_TOTAL = [] 

for perm in itertools.product(GRID_DROPOUT, HIDDEN_DIM, GRID_EMBED_DIM, GRID_OPT_SELECT, GRID_LR):
    GRID_TOTAL.append(perm)

len(GRID_TOTAL) ## 162 models
GRID_MODELS = []
GRID_OPT = []

for i in range(len(GRID_TOTAL)):
    
    DROPOUT = GRID_TOTAL[i][0]
    HIDDEN_DIM = GRID_TOTAL[i][1]
    GRID_EMBED_DIM = GRID_TOTAL[i][2]
    OPT = GRID_TOTAL[i][3]
    LR = GRID_TOTAL[i][4]
    
    GRID_MODELS.append(LSTM(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL, DROPOUT, PAD_IDX).to(device))
    GRID_OPT.append(eval("optim."+OPT)(GRID_MODELS[i].parameters(),LR))

# %%
NUM_EPOCHS = 10
GRID_TRACKER = []
Val_Tracker = []
best_valid_loss = float('inf')
for i in range(len(GRID_MODELS)):
  print("Params", GRID_MODELS[i].parameters)
  for epoch in range(NUM_EPOCHS):
    start_time = time.time()
    criterion = nn.BCEWithLogitsLoss()
    criterion.to(device)
    train_loss, train_acc = train(GRID_MODELS[i], train_iterator, GRID_OPT[i], criterion)
    valid_loss, valid_acc = evaluate(GRID_MODELS[i], valid_iterator, criterion)
    # Save val_acc
    Val_Tracker.append(valid_acc)
       
    end_time = time.time()
    mins, secs = timer(start_time,end_time)
    print("Epoch {}:".format(epoch+1))
    print(GRID_MODELS[i])
    #print(GRID_TOTAL[GRID_TRACKER.index(np.max(GRID_TRACKER))])
    print("\t Total Time: {}m {}s".format(mins, secs))
    print("\t Train Loss {} | Train Accuracy: {}%".format(round(train_loss, 2), round(train_acc*100, 2)))
    print("\t Validation Loss {} | Validation Accuracy: {}%".format(round(valid_loss, 2), round(valid_acc*100, 2)))
  GRID_TRACKER.append(np.max([Val_Tracker[x] for x in range(len(Val_Tracker))]))
# Out:
# Streaming output truncated to the last 5000 lines.
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.73 | Train Accuracy: 50.7%
# 	 Validation Loss 0.72 | Validation Accuracy: 49.92%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.61%
# 	 Validation Loss 0.7 | Validation Accuracy: 53.56%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.29 | Train Accuracy: 87.88%
# 	 Validation Loss 0.57 | Validation Accuracy: 78.77%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.28 | Train Accuracy: 88.33%
# 	 Validation Loss 0.54 | Validation Accuracy: 78.99%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.27 | Train Accuracy: 88.57%
# 	 Validation Loss 0.56 | Validation Accuracy: 78.81%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.27 | Train Accuracy: 88.76%
# 	 Validation Loss 0.62 | Validation Accuracy: 78.57%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.26 | Train Accuracy: 89.13%
# 	 Validation Loss 0.62 | Validation Accuracy: 78.41%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.26 | Train Accuracy: 89.41%
# 	 Validation Loss 0.62 | Validation Accuracy: 78.59%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.25 | Train Accuracy: 89.41%
# 	 Validation Loss 0.62 | Validation Accuracy: 78.33%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.25 | Train Accuracy: 89.71%
# 	 Validation Loss 0.62 | Validation Accuracy: 78.1%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.24 | Train Accuracy: 89.91%
# 	 Validation Loss 0.65 | Validation Accuracy: 78.21%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.24 | Train Accuracy: 89.89%
# 	 Validation Loss 0.67 | Validation Accuracy: 77.99%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.41 | Train Accuracy: 81.07%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.52%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.4 | Train Accuracy: 81.59%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.0%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.4 | Train Accuracy: 81.85%
# 	 Validation Loss 0.46 | Validation Accuracy: 79.98%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.39 | Train Accuracy: 82.48%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.79%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.39 | Train Accuracy: 82.64%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.97%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.38 | Train Accuracy: 83.13%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.36%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.37 | Train Accuracy: 83.43%
# 	 Validation Loss 0.46 | Validation Accuracy: 80.21%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.37 | Train Accuracy: 83.76%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.46%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.36 | Train Accuracy: 84.07%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.54%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.36 | Train Accuracy: 84.3%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.53%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.65%
# 	 Validation Loss 0.71 | Validation Accuracy: 50.84%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.79 | Train Accuracy: 50.27%
# 	 Validation Loss 0.73 | Validation Accuracy: 50.77%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.78 | Train Accuracy: 50.65%
# 	 Validation Loss 0.71 | Validation Accuracy: 52.28%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.78 | Train Accuracy: 50.22%
# 	 Validation Loss 0.84 | Validation Accuracy: 49.72%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.77 | Train Accuracy: 50.54%
# 	 Validation Loss 0.86 | Validation Accuracy: 49.6%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.78 | Train Accuracy: 50.36%
# 	 Validation Loss 0.78 | Validation Accuracy: 51.05%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.78 | Train Accuracy: 50.86%
# 	 Validation Loss 0.81 | Validation Accuracy: 50.88%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.79 | Train Accuracy: 50.77%
# 	 Validation Loss 0.7 | Validation Accuracy: 53.05%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.8 | Train Accuracy: 50.58%
# 	 Validation Loss 0.79 | Validation Accuracy: 50.68%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.79 | Train Accuracy: 50.54%
# 	 Validation Loss 0.75 | Validation Accuracy: 50.41%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.34 | Train Accuracy: 85.46%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.42%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.33 | Train Accuracy: 85.72%
# 	 Validation Loss 0.46 | Validation Accuracy: 79.96%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.32 | Train Accuracy: 86.17%
# 	 Validation Loss 0.51 | Validation Accuracy: 79.39%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.32 | Train Accuracy: 86.36%
# 	 Validation Loss 0.48 | Validation Accuracy: 79.69%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.31 | Train Accuracy: 86.52%
# 	 Validation Loss 0.51 | Validation Accuracy: 79.64%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.31 | Train Accuracy: 86.87%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.19%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.3 | Train Accuracy: 87.24%
# 	 Validation Loss 0.56 | Validation Accuracy: 79.4%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.3 | Train Accuracy: 87.33%
# 	 Validation Loss 0.52 | Validation Accuracy: 79.1%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.3 | Train Accuracy: 87.47%
# 	 Validation Loss 0.53 | Validation Accuracy: 78.99%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.29 | Train Accuracy: 87.61%
# 	 Validation Loss 0.55 | Validation Accuracy: 79.22%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.42 | Train Accuracy: 80.43%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.52%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.42 | Train Accuracy: 81.08%
# 	 Validation Loss 0.44 | Validation Accuracy: 79.9%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.41 | Train Accuracy: 81.41%
# 	 Validation Loss 0.46 | Validation Accuracy: 79.74%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.4 | Train Accuracy: 81.55%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.92%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.4 | Train Accuracy: 81.93%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.39%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.39 | Train Accuracy: 82.28%
# 	 Validation Loss 0.44 | Validation Accuracy: 79.95%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.39 | Train Accuracy: 82.52%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.38%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.38 | Train Accuracy: 82.79%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.28%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.38 | Train Accuracy: 83.12%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.38%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.37 | Train Accuracy: 83.55%
# 	 Validation Loss 0.46 | Validation Accuracy: 80.61%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.37%
# 	 Validation Loss 0.71 | Validation Accuracy: 50.73%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.68%
# 	 Validation Loss 0.71 | Validation Accuracy: 52.21%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.69%
# 	 Validation Loss 0.71 | Validation Accuracy: 52.57%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.78%
# 	 Validation Loss 0.71 | Validation Accuracy: 51.89%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.79%
# 	 Validation Loss 0.7 | Validation Accuracy: 52.04%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.56%
# 	 Validation Loss 0.71 | Validation Accuracy: 50.79%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.73 | Train Accuracy: 50.38%
# 	 Validation Loss 0.71 | Validation Accuracy: 51.13%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.64%
# 	 Validation Loss 0.7 | Validation Accuracy: 52.86%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.26%
# 	 Validation Loss 0.71 | Validation Accuracy: 51.17%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.73 | Train Accuracy: 50.32%
# 	 Validation Loss 0.71 | Validation Accuracy: 51.44%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.28 | Train Accuracy: 88.19%
# 	 Validation Loss 0.57 | Validation Accuracy: 79.19%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.28 | Train Accuracy: 88.42%
# 	 Validation Loss 0.56 | Validation Accuracy: 78.66%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.27 | Train Accuracy: 88.71%
# 	 Validation Loss 0.57 | Validation Accuracy: 78.86%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.26 | Train Accuracy: 89.19%
# 	 Validation Loss 0.58 | Validation Accuracy: 78.73%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.25 | Train Accuracy: 89.46%
# 	 Validation Loss 0.59 | Validation Accuracy: 78.57%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.25 | Train Accuracy: 89.6%
# 	 Validation Loss 0.59 | Validation Accuracy: 78.63%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.25 | Train Accuracy: 89.69%
# 	 Validation Loss 0.63 | Validation Accuracy: 78.11%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.24 | Train Accuracy: 89.97%
# 	 Validation Loss 0.65 | Validation Accuracy: 77.8%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.24 | Train Accuracy: 90.01%
# 	 Validation Loss 0.63 | Validation Accuracy: 77.88%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.23 | Train Accuracy: 90.25%
# 	 Validation Loss 0.65 | Validation Accuracy: 77.89%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.41 | Train Accuracy: 81.11%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.09%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.4 | Train Accuracy: 81.57%
# 	 Validation Loss 0.46 | Validation Accuracy: 80.12%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.4 | Train Accuracy: 82.07%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.47%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.39 | Train Accuracy: 82.39%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.32%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.38 | Train Accuracy: 82.79%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.71%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.38 | Train Accuracy: 83.1%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.45%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.37 | Train Accuracy: 83.62%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.86%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.37 | Train Accuracy: 83.94%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.89%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.36 | Train Accuracy: 84.1%
# 	 Validation Loss 0.45 | Validation Accuracy: 81.02%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.35 | Train Accuracy: 84.33%
# 	 Validation Loss 0.46 | Validation Accuracy: 80.88%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.71%
# 	 Validation Loss 0.74 | Validation Accuracy: 51.56%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.94%
# 	 Validation Loss 0.77 | Validation Accuracy: 50.34%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.75 | Train Accuracy: 50.65%
# 	 Validation Loss 0.78 | Validation Accuracy: 50.31%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.73%
# 	 Validation Loss 0.79 | Validation Accuracy: 50.61%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.63%
# 	 Validation Loss 0.82 | Validation Accuracy: 49.72%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.54%
# 	 Validation Loss 0.72 | Validation Accuracy: 51.08%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.55%
# 	 Validation Loss 0.7 | Validation Accuracy: 53.06%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.75 | Train Accuracy: 50.81%
# 	 Validation Loss 0.79 | Validation Accuracy: 50.65%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.76 | Train Accuracy: 50.74%
# 	 Validation Loss 0.74 | Validation Accuracy: 51.56%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.75 | Train Accuracy: 50.92%
# 	 Validation Loss 0.71 | Validation Accuracy: 51.61%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.33 | Train Accuracy: 85.71%
# 	 Validation Loss 0.47 | Validation Accuracy: 79.81%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.32 | Train Accuracy: 86.3%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.58%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.32 | Train Accuracy: 86.36%
# 	 Validation Loss 0.49 | Validation Accuracy: 79.58%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.31 | Train Accuracy: 86.75%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.31%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.31 | Train Accuracy: 86.93%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.38%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.3 | Train Accuracy: 87.22%
# 	 Validation Loss 0.52 | Validation Accuracy: 79.46%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.3 | Train Accuracy: 87.46%
# 	 Validation Loss 0.55 | Validation Accuracy: 79.27%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.29 | Train Accuracy: 87.81%
# 	 Validation Loss 0.54 | Validation Accuracy: 79.44%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.29 | Train Accuracy: 87.92%
# 	 Validation Loss 0.56 | Validation Accuracy: 79.27%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.28 | Train Accuracy: 87.99%
# 	 Validation Loss 0.53 | Validation Accuracy: 79.43%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.42 | Train Accuracy: 80.67%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.45%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.42 | Train Accuracy: 80.89%
# 	 Validation Loss 0.46 | Validation Accuracy: 79.55%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.41 | Train Accuracy: 81.4%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.68%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.4 | Train Accuracy: 81.62%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.03%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.4 | Train Accuracy: 82.3%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.0%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.39 | Train Accuracy: 82.38%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.29%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.39 | Train Accuracy: 82.82%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.36%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.38 | Train Accuracy: 82.99%
# 	 Validation Loss 0.44 | Validation Accuracy: 80.46%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.38 | Train Accuracy: 83.3%
# 	 Validation Loss 0.47 | Validation Accuracy: 79.92%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 64, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.37 | Train Accuracy: 83.52%
# 	 Validation Loss 0.46 | Validation Accuracy: 80.42%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.75 | Train Accuracy: 51.35%
# 	 Validation Loss 0.72 | Validation Accuracy: 52.12%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.75 | Train Accuracy: 50.69%
# 	 Validation Loss 0.71 | Validation Accuracy: 53.51%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.75 | Train Accuracy: 50.69%
# 	 Validation Loss 0.73 | Validation Accuracy: 51.23%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.76 | Train Accuracy: 50.34%
# 	 Validation Loss 0.76 | Validation Accuracy: 51.08%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.76 | Train Accuracy: 50.4%
# 	 Validation Loss 0.73 | Validation Accuracy: 51.4%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.75 | Train Accuracy: 50.49%
# 	 Validation Loss 0.72 | Validation Accuracy: 52.37%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.75 | Train Accuracy: 50.44%
# 	 Validation Loss 0.73 | Validation Accuracy: 50.92%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 2s
# 	 Train Loss 0.75 | Train Accuracy: 50.54%
# 	 Validation Loss 0.75 | Validation Accuracy: 49.87%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 100, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=200, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.76 | Train Accuracy: 50.58%
# 	 Validation Loss 0.72 | Validation Accuracy: 50.25%
# Epoch 10:
# LSTM(
# ...
# 	 Train Loss 0.38 | Train Accuracy: 83.18%
# 	 Validation Loss 0.51 | Validation Accuracy: 77.96%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.37 | Train Accuracy: 83.64%
# 	 Validation Loss 0.45 | Validation Accuracy: 80.08%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.35 | Train Accuracy: 84.4%
# 	 Validation Loss 0.46 | Validation Accuracy: 80.04%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.34 | Train Accuracy: 85.25%
# 	 Validation Loss 0.46 | Validation Accuracy: 79.55%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.33 | Train Accuracy: 85.78%
# 	 Validation Loss 0.47 | Validation Accuracy: 79.81%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.31 | Train Accuracy: 86.42%
# 	 Validation Loss 0.5 | Validation Accuracy: 80.05%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.3 | Train Accuracy: 86.96%
# 	 Validation Loss 0.48 | Validation Accuracy: 79.65%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.29 | Train Accuracy: 87.58%
# 	 Validation Loss 0.52 | Validation Accuracy: 79.56%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.28 | Train Accuracy: 88.12%
# 	 Validation Loss 0.52 | Validation Accuracy: 79.33%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.27 | Train Accuracy: 88.6%
# 	 Validation Loss 0.52 | Validation Accuracy: 79.49%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.26 | Train Accuracy: 89.05%
# 	 Validation Loss 0.54 | Validation Accuracy: 79.38%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.17 | Train Accuracy: 50.78%
# 	 Validation Loss 1.4 | Validation Accuracy: 50.46%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.11 | Train Accuracy: 51.24%
# 	 Validation Loss 1.03 | Validation Accuracy: 50.88%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.17 | Train Accuracy: 50.94%
# 	 Validation Loss 1.17 | Validation Accuracy: 51.24%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.13 | Train Accuracy: 51.12%
# 	 Validation Loss 1.62 | Validation Accuracy: 50.01%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 1.12 | Train Accuracy: 50.85%
# 	 Validation Loss 1.36 | Validation Accuracy: 50.14%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.18 | Train Accuracy: 50.53%
# 	 Validation Loss 1.34 | Validation Accuracy: 50.61%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.19 | Train Accuracy: 50.86%
# 	 Validation Loss 0.79 | Validation Accuracy: 51.97%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.2 | Train Accuracy: 50.49%
# 	 Validation Loss 1.63 | Validation Accuracy: 49.81%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.19 | Train Accuracy: 50.55%
# 	 Validation Loss 1.13 | Validation Accuracy: 50.59%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 1.18 | Train Accuracy: 50.93%
# 	 Validation Loss 3.04 | Validation Accuracy: 50.32%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.35 | Train Accuracy: 84.79%
# 	 Validation Loss 0.52 | Validation Accuracy: 78.22%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.35 | Train Accuracy: 84.91%
# 	 Validation Loss 0.47 | Validation Accuracy: 79.8%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.34 | Train Accuracy: 85.2%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.71%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.34 | Train Accuracy: 85.35%
# 	 Validation Loss 0.48 | Validation Accuracy: 79.54%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.34 | Train Accuracy: 85.54%
# 	 Validation Loss 0.51 | Validation Accuracy: 78.69%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.33 | Train Accuracy: 85.76%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.91%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.33 | Train Accuracy: 85.84%
# 	 Validation Loss 0.47 | Validation Accuracy: 79.94%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.33 | Train Accuracy: 85.89%
# 	 Validation Loss 0.47 | Validation Accuracy: 79.54%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.33 | Train Accuracy: 86.13%
# 	 Validation Loss 0.51 | Validation Accuracy: 79.49%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.33 | Train Accuracy: 86.03%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.6%
# Params <bound method Module.parameters of LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )>
# Epoch 1:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.37 | Train Accuracy: 83.18%
# 	 Validation Loss 0.45 | Validation Accuracy: 79.56%
# Epoch 2:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 3s
# 	 Train Loss 0.36 | Train Accuracy: 83.89%
# 	 Validation Loss 0.46 | Validation Accuracy: 80.21%
# Epoch 3:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.35 | Train Accuracy: 84.68%
# 	 Validation Loss 0.46 | Validation Accuracy: 79.94%
# Epoch 4:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.33 | Train Accuracy: 85.27%
# 	 Validation Loss 0.46 | Validation Accuracy: 79.78%
# Epoch 5:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.32 | Train Accuracy: 86.09%
# 	 Validation Loss 0.48 | Validation Accuracy: 79.87%
# Epoch 6:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.31 | Train Accuracy: 86.54%
# 	 Validation Loss 0.48 | Validation Accuracy: 80.17%
# Epoch 7:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.3 | Train Accuracy: 87.21%
# 	 Validation Loss 0.5 | Validation Accuracy: 79.16%
# Epoch 8:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.29 | Train Accuracy: 87.69%
# 	 Validation Loss 0.51 | Validation Accuracy: 79.07%
# Epoch 9:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.28 | Train Accuracy: 88.13%
# 	 Validation Loss 0.52 | Validation Accuracy: 79.78%
# Epoch 10:
# LSTM(
#   (embedding): Embedding(30002, 100, padding_idx=1)
#   (encoder): LSTM(100, 256, num_layers=2, dropout=0.4, bidirectional=True)
#   (predictor): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# 	 Total Time: 0m 4s
# 	 Train Loss 0.27 | Train Accuracy: 88.65%
# 	 Validation Loss 0.53 | Validation Accuracy: 79.19%

# %%
####(0.4, 100, 50, 'Adam', 0.001)
GRID_TOTAL[GRID_TRACKER.index(np.max(GRID_TRACKER))] 
np.max(GRID_TRACKER)
print(GRID_TOTAL[GRID_TRACKER.index(np.max(GRID_TRACKER))])

print("mean: %f and std dev: %f " % (np.mean(GRID_TRACKER), np.std(GRID_TRACKER)))
# Out:
# (0.4, 100, 50, 'Adam', 0.001)
# mean: 0.806755 and std dev: 0.021972

# %%
GRID_TRACKER.index(np.max(GRID_TRACKER))
len(GRID_TRACKER)
# Out:
# 162

# %%
def training_plot(epoch_num, train_loss_list, train_acc_list, valid_loss_list, valid_acc_list):
    plt.figure()
    plt.plot(range(epoch_num), train_loss_list, color='blue', linestyle='-', label='train_loss')
    plt.plot(range(epoch_num), valid_loss_list, color='green', linestyle='--', label='val_loss')
    plt.legend()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training and validation loss')
    plt.grid()
    plt.show()

    plt.figure()
    plt.plot(range(epoch_num), train_acc_list, color='blue', linestyle='-', label='train_acc')
    plt.plot(range(epoch_num), valid_acc_list, color='green', linestyle='--', label='val_acc')
    plt.legend()
    plt.xlabel('epoch')
    plt.ylabel('acc')
    plt.title('Training and validation accuracy')
    plt.grid()
    plt.show()

# %%
# Number of epochs
NUM_EPOCHS = 10

# Lowest validation lost
best_valid_loss = float('inf')
train_loss_list = []
train_acc_list  = []
valid_loss_list = []
valid_acc_list  = []

for epoch in range(NUM_EPOCHS):

    start_time = time.time()
    
    # Evaluate training loss and accuracy
    train_loss, train_acc = train(model, train_iterator, optimizer, criterion)
    # Evaluate validation loss and accuracy
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()

    mins, secs = timer(start_time, end_time)
    
    # At each epoch, if the validation loss is the best
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        # Save the parameters of the model
        torch.save(model.state_dict(), 'lstmG-best.pt')

    print("Epoch {}:".format(epoch+1))
    print("\t Total Time: {}m {}s".format(mins, secs))
    print("\t Train Loss {} | Train Accuracy: {}%".format(round(train_loss, 2), round(train_acc*100, 2)))
    print("\t Validation Loss {} | Validation Accuracy: {}%".format(round(valid_loss, 2), round(valid_acc*100, 2)))

    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)
    valid_loss_list.append(valid_loss)
    valid_acc_list.append(valid_acc)

training_plot(NUM_EPOCHS, train_loss_list, train_acc_list, valid_loss_list, valid_acc_list)
# Out:
# Epoch 1:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.61 | Train Accuracy: 65.86%
# 	 Validation Loss 0.5 | Validation Accuracy: 76.24%
# Epoch 2:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.53 | Train Accuracy: 73.31%
# 	 Validation Loss 0.47 | Validation Accuracy: 77.96%
# Epoch 3:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.5 | Train Accuracy: 76.01%
# 	 Validation Loss 0.45 | Validation Accuracy: 78.91%
# Epoch 4:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.47 | Train Accuracy: 77.64%
# 	 Validation Loss 0.44 | Validation Accuracy: 79.32%
# Epoch 5:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.46 | Train Accuracy: 78.75%
# 	 Validation Loss 0.43 | Validation Accuracy: 79.71%
# Epoch 6:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.44 | Train Accuracy: 79.61%
# 	 Validation Loss 0.43 | Validation Accuracy: 80.17%
# Epoch 7:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.43 | Train Accuracy: 80.15%
# 	 Validation Loss 0.43 | Validation Accuracy: 79.84%
# Epoch 8:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.42 | Train Accuracy: 81.12%
# 	 Validation Loss 0.42 | Validation Accuracy: 80.0%
# Epoch 9:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.41 | Train Accuracy: 81.59%
# 	 Validation Loss 0.43 | Validation Accuracy: 80.66%
# Epoch 10:
# 	 Total Time: 0m 5s
# 	 Train Loss 0.4 | Train Accuracy: 82.13%
# 	 Validation Loss 0.42 | Validation Accuracy: 80.61%

# %%
# Load the model with the best validation loss
model.load_state_dict(torch.load('lstmG-best.pt'))

# Evaluate test loss and accuracy
test_loss, test_acc = evaluate(model, test_iterator, criterion)

print("Test Loss: {} | Test Acc: {}%".format(round(test_loss, 2), round(test_acc*100, 2)))
# Out:
# Test Loss: 0.43 | Test Acc: 80.47%

# %%
nlp = spacy.load('en')

def predict(model, text, tokenized=True):
    """
    Given a tweet, predict the sentiment.

    text - a string or a a list of tokens
    tokenized - True if text is a list of tokens, False if passing in a string
    """

    # Sets the model to evaluation mode
    model.eval()

    if tokenized == False:
        # Tokenizes the sentence
        tokens = [token.text for token in nlp.tokenizer(text)]
    else:
        tokens = text

    # Index the tokens by converting to the integer representation from the vocabulary
    indexed_tokens = [TEXT.vocab.stoi[t] for t in tokens]
    # Get the length of the text
    length = [len(indexed_tokens)]
    # Convert the indices to a tensor
    tensor = torch.LongTensor(indexed_tokens).to(device)
    # Add a batch dimension by unsqueezeing
    tensor = tensor.unsqueeze(1)
    # Converts the length into a tensor
    length_tensor = torch.LongTensor(length)
    # Convert prediction to be between 0 and 1 with the sigmoid function
    prediction = torch.sigmoid(model(tensor, length_tensor))

    # Return a single value from the prediction
    return prediction.item()

# %%
print("Tweet: {}".format(TreebankWordDetokenizer().detokenize(test_data[20].text)))

print("Prediction: {}".format(round(predict(model, test_data[20].text), 2)))

print("True Label: {}".format(test_data[10].target))
# Out:
# Tweet: working and wishing my back wasn't killing me, i barely slept at all last night!
# Prediction: 0.06
# True Label: 1

# %%
# List to append data to
d = []


for idx in range(10):

    # Detokenize the tweets from the test set
    tweet = TreebankWordDetokenizer().detokenize(test_data[idx].text)
                                                 
    # Append tweet, prediction, and true label
    d.append({'Tweet': tweet, 'Prediction': predict(model, test_data[idx].text), 'True Label': test_data[idx].target})

# Convert list to dataframe
pd.DataFrame(d)
# Out:
#                                                Tweet  Prediction True Label
# 0   dare i say it?! my fire is beginning to burn out    0.222651          0
# 1  what a disappointing women's french open final...    0.226705          0
# 2                                       thanks honey    0.991260          1
# 3  hey i watched a previous broadcast & paused it...    0.717787          0
# 4                     bruvas court case fridayy (n )    0.545866          0
# 5  uhmmm .. school is coming here in the philippi...    0.777797          1
# 6                having mates with my friend silvia!    0.684576          1
# 7              going to tiger direct . going mobile.    0.599441          1
# 8  just took a fantabulous nap . now gonna have s...    0.923377          1
# 9                           no! stop making me fail.    0.110928          0

# %%
fields = [('Tweet', TEXT), ('Subjectivity',None),('Date',None),('Polarity',None),
      ('Sentiment',LABEL)]

# Apply field definition to create torch dataset
testdf = torchtext.data.TabularDataset(
        path="/content/drive/MyDrive/Colab Notebooks/trump_tweets_v3.csv",
        format="CSV",
        fields=fields,
        skip_header=True)

# %%
len(testdf)
# Out:
# 5943

# %%
d = []


for idx in range(len(testdf)):

    # Detokenize the tweets from the test set
    tweet = TreebankWordDetokenizer().detokenize(testdf[idx].Tweet)
                                                 
    # Append tweet, prediction, and true label
    d.append({'Tweet': tweet, 'Prediction': predict(model, testdf[idx].Tweet), 'True Label': testdf[idx].Sentiment})

# Convert list to dataframe
newdf = pd.DataFrame(d)

# %%
newdf.to_csv("predict_lstm_glove.csv", header=True, index=False)

# %%
positive = newdf[newdf['True Label'] == 'Positive']
negative = newdf[newdf['True Label']== 'Negative']
total = positive.shape[0] + negative.shape[0]

print(str(positive.shape[0]/(total)*100) + " % of positive tweets")
print(str(negative.shape[0]/(total)*100) + " % of negative tweets")
# Out:
# 70.75551068483931 % of positive tweets
# 29.244489315160692 % of negative tweets

# %%
positivePred = newdf[newdf['Prediction'] >= 0.50]
negativePred = newdf[newdf['Prediction'] < 0.50]
print(str(positivePred.shape[0]/(newdf.shape[0])*100) + " % of positive tweets")
print(str(negativePred.shape[0]/(newdf.shape[0])*100) + " % of negative tweets")
# Out:
# 68.38297156318359 % of positive tweets
# 31.617028436816426 % of negative tweets

# %%
newdf.head(20)
# Out:
#                                                 Tweet  Prediction True Label
# 0   i was thrilled to be back in the great city of...    0.946649   Positive
# 1   read: letter to surveillance court obtained by...    0.384301   Positive
# 2   the unsolicited mail in ballot scam is a major...    0.088715   Positive
# 3   very friendly telling of events here about com...    0.439532   Positive
# 4   president   announced historic steps to protec...    0.639122   Positive
# 5             getting a little exercise this morning!    0.889668   Negative
# 6   the economic boom continues! \n\n 273 k jobs a...    0.897589   Positive
# 7   vindman's behavior is a scandal . he should be...    0.740593   Negative
# 8   $ 13.9 m is heading to new orleans in   fundin...    0.809241   Positive
# 9                         tonight at 9:00 p.m. enjoy!    0.957304   Positive
# 10                               more voter fraud ...    0.316706   Positive
# 11  ... based on decisions being rendered now, thi...    0.879538   Positive
# 12  the fbi lied to the fisa court 17 times, using...    0.697628   Negative
# 13  big victory for patients â federal court uph...    0.512799   Positive
# 14  everything weâre doing right now is time - s...    0.448383   Positive
# 15  fun fact for patriots: presidents thomas jeffe...    0.354552   Positive
# 16  rushing him out of basement after seeing some ...    0.656997   Negative
# 17                           sleepy eyes fails again!    0.128403   Negative
# 18                                      happy easter!    0.991516   Positive
# 19  much more âdisinformationâ coming out of c...    0.480291   Negative
